# %%
pip install nltk

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk

# %%
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Package alpino is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_eng is already
# [nltk_data]    |       up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger_ru is already
# [nltk_data]    |       up-to-date!
# ...

# %%
f=open('/content/drive/MyDrive/Jonathan Livingston Seagull.en.ur.txt')
raw=f.read()

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
tokens=word_tokenize(raw)
print(tokens[:20])
# Out:
# ['جوناتھن', 'لیونگسٹن', 'سیگل', '-', 'ایک', 'کہانی', 'حصہ', 'ایک', 'یہ', 'صبح', 'تھی،', 'اور', 'نئے', 'سورج', 'نے', 'نرمی', 'کی', 'لہروں', 'میں', 'سونا']

# %%
# Tokenizing sentences
sents = sent_tokenize(raw)
print(sents[:2])
# Out:
# ['جوناتھن لیونگسٹن سیگل - ایک کہانی\n\n\n\nحصہ ایک\n\nیہ صبح تھی، اور نئے سورج نے نرمی کی لہروں میں سونا چمکایا\nسمندر\n\nساحل سے ایک میل کے فاصلے پر ایک ماہی گیر کشتی نے پانی کو جھنجھوڑا، اور اس کے لیے لفظ\nایک ہزار بگلوں کے ہجوم تک ناشتے کا جھنڈ ہوا میں اڑتا رہا۔\nڈاج کرنے اور کھانے کے ٹکڑوں کے لیے لڑنے آیا۔ یہ ایک اور مصروف دن کا آغاز تھا۔\n\nلیکن اکیلے ہی نکلیں، خود کشتی اور ساحل سے پرے، جوناتھن\nلیونگسٹن سیگل مشق کر رہا تھا۔ آسمان میں سو فٹ نیچے اس نے اپنا\nجالے والے پاؤں، اپنی چونچ اٹھائی، اور ایک دردناک سخت بٹی ہوئی وکر کو پکڑنے کے لیے تناؤ\nاس کے پروں کے ذریعے.', 'گھماؤ کا مطلب تھا کہ وہ آہستہ آہستہ اڑ جائے گا، اور اب وہ\nاس وقت تک سست ہوا جب تک کہ ہوا اس کے چہرے پر سرگوشی نہیں کرتی، جب تک کہ سمندر ساکت نہ ہو جائے۔\nاس کے نیچے.']

# %%
raw
# Out:
# 'جوناتھن لیونگسٹن سیگل - ایک کہانی\n\n\n\nحصہ ایک\n\nیہ صبح تھی، اور نئے سورج نے نرمی کی لہروں میں سونا چمکایا\nسمندر\n\nساحل سے ایک میل کے فاصلے پر ایک ماہی گیر کشتی نے پانی کو جھنجھوڑا، اور اس کے لیے لفظ\nایک ہزار بگلوں کے ہجوم تک ناشتے کا جھنڈ ہوا میں اڑتا رہا۔\nڈاج کرنے اور کھانے کے ٹکڑوں کے لیے لڑنے آیا۔ یہ ایک اور مصروف دن کا آغاز تھا۔\n\nلیکن اکیلے ہی نکلیں، خود کشتی اور ساحل سے پرے، جوناتھن\nلیونگسٹن سیگل مشق کر رہا تھا۔ آسمان میں سو فٹ نیچے اس نے اپنا\nجالے والے پاؤں، اپنی چونچ اٹھائی، اور ایک دردناک سخت بٹی ہوئی وکر کو پکڑنے کے لیے تناؤ\nاس کے پروں کے ذریعے. گھماؤ کا مطلب تھا کہ وہ آہستہ آہستہ اڑ جائے گا، اور اب وہ\nاس وقت تک سست ہوا جب تک کہ ہوا اس کے چہرے پر سرگوشی نہیں کرتی، جب تک کہ سمندر ساکت نہ ہو جائے۔\nاس کے نیچے. اس نے شدید ارتکاز میں اپنی آنکھیں تنگ کیں، سانس روکی،\nمجبور ایک... سنگل... مزید... انچ... کا... وکر.... پھر اس کے پنکھ\nگھبرا کر وہ رک گیا اور گر گیا۔\n\nسیگل، جیسا کہ آپ جانتے ہیں، کبھی نہیں لڑتے، کبھی نہیں رکتے۔ ہوا میں سٹال کے لئے ہے\nوہ رسوا ہوئے اور 
# ...

# %%
len(raw)
# Out:
# 48261

# %%
type(raw)
# Out:
# str

# %%
from nltk.text import Text

# Create an NLTK Text object from the raw string:
text = Text(tokens)  # Note: Use the tokens created with word_tokenize

# Now you can use concordance:
text.concordance('پرواز')
# Out:
# Displaying 25 of 34 matches:
# نہیں تھا۔ عام پرندہ زیادہ تر گلوں نے پرواز کے آسان ترین حقائق سے زیادہ جاننے کی
# کھا رہا تھا جو اہمیت رکھتا تھا، لیکن پرواز . کسی بھی چیز سے زیادہ، جوناتھن لیون
# ر، لیکن جب اس نے اس سے کم اونچائی پر پرواز کی۔ پانی کے اوپر اس کے پروں کا نصف،
# جون؟ آپ پیلیکن، الباٹراس کے لیے نچلی پرواز کیوں نہیں چھوڑ سکتے؟ تم کیوں نہیں کھ
#  جانتے ہیں۔ آپ یہ مت بھولنا کہ آپ کی پرواز کی وجہ ہے۔ کھانے کے لیے `` جوناتھن ن
# سارا وقت سیکھنے میں صرف کر سکتا ہوں۔ پرواز سیکھنے کو بہت کچھ ہے ! ابھی زیادہ دی
# تنہائی کا نہیں تھا، وہ دوسرا گل تھا۔ پرواز کے جلال پر یقین کرنے سے انکار کر دیا
# نی سے، پوزیشن میں بند ہو گئے۔ وہ سست پرواز کے بارے میں جانتا تھا۔ اس نے اپنے پر
# سکراتے ہوئے اس کے ساتھ لپکا۔ وہ سطحی پرواز پر بحال ہوا اور بولنے سے پہلے کچھ دی
# محسوس کیا کہ وہ اپنی سطح کے قریب ہے۔ پرواز کی زیادہ سے زیادہ رفتار . دو سو تہتر
# یہ بہت زیادہ تھا۔ اس کے پرانے سطح کی پرواز کے ریکارڈ سے تیز، یہ اب بھی ایک حد ت
# ...

# %%
text.similar('پرواز')
# Out:
# اس سوچ کشتیوں زندگی محبت کے ہوا کھانے آسمان نہیں اپنے زیادہ گل قسم سطح
# گرنے لینڈنگ سلائڈ صرف کیا

# %%
text.common_contexts(["پرواز"])
# Out:
# نے_کے لیکن_کسی پر_پانی نچلی_کیوں کی_کی سکتا_سیکھنے گل_کے سست_کے
# سطحی_پر قریب_کی کی_کے پر_کے گھنٹوں_کی ساتھ_کی یا_نہیں سے_کیونکہ
# ہے_کہیں نہیں_کرنے کو_کو سے_کرنے

# %%
text.dispersion_plot(["جوناتھن", "آزادی", "حد","پرواز","خوف"])

# %%
text.generate()
# Out:
# Building ngram index...
# نے آنکھیں بند کر لیں۔ یہ اس صبح مغرب سے اڑان بھرے، ان میں سے صرف ایک
# ماہ بعد جوناتھن کو زیادہ قریب سے سنا۔ اس کے بارے میں حیران ہوں، جون،
# '' سلیوان نے سر ہلایا۔ `` آپ کہتے ہیں کہ آپ معاف کر دوں گا ... '' آواز
# اس کی سوچ کے اندر پھنس گیا جس سے وہ کھڑے ہیں ! روزمرہ کی زندگی بہت
# مختصر ہے، اور آپ اپنے وقت سے ہزار سال آگے ہیں۔ جوناتھن نے کہا، `` آپ
# دوبارہ سیکھ رہے ہیں، جوناتھن سیگل، `` انہوں نے کہا۔ `` تمہارے پاس کم
# ہے۔ کسی بھی
# "نے آنکھیں بند کر لیں۔ یہ اس صبح مغرب سے اڑان بھرے، ان میں سے صرف ایک\nماہ بعد جوناتھن کو زیادہ قریب سے سنا۔ اس کے بارے میں حیران ہوں، جون،\n'' سلیوان نے سر ہلایا۔ `` آپ کہتے ہیں کہ آپ معاف کر دوں گا ... '' آواز\nاس کی سوچ کے اندر پھنس گیا جس سے وہ کھڑے ہیں ! روزمرہ کی زندگی بہت\nمختصر ہے، اور آپ اپنے وقت سے ہزار سال آگے ہیں۔ جوناتھن نے کہا، `` آپ\nدوبارہ سیکھ رہے ہیں، جوناتھن سیگل، `` انہوں نے کہا۔ `` تمہارے پاس کم\nہے۔ کسی بھی"

# %%
sorted(set(text))
# Out:
# ['!',
#  "'",
#  "''",
#  "'لیکن",
#  "'میں",
#  '-',
#  '.',
#  '..',
#  '...',
#  '....',
#  '1',
#  '7',
#  '7/اپنے',
#  ':',
#  'Flock',
#  '``',
#  'a',
#  'aaakkk',
#  'cartwheel،',
#  'grockles',
#  'kame',
#  'nedt',
#  'screes',
#  'squawks',
#  '؟',
#  'آ',
#  'آؤ',
#  'آؤ،',
#  'آؤٹ',
#  'آئی',
#  'آئی،',
#  'آئیڈیا',
#  'آئیے',
#  'آئے',
#  'آئے،',
#  'آتا',
#  'آتا،',
#  'آتی',
#  'آج',
#  'آخر',
#  'آخری',
#  'آدھا',
#  'آدھی',
#  'آدھے',
#  'آرام',
#  'آزاد',
#  'آزادی',
#  'آزادی،',
#  'آزمانے',
#  'آس',
#  'آسان',
#  'آسانی',
#  'آسمان',
#  'آسمان،',
#  'آسمانوں',
#  'آغاز',
#  'آف',
#  'آفتاب',
#  'آمدید',
#  'آنکھ',
#  'آنکھوں',
#  'آنکھیں',
#  'آنے',
#  'آواز',
#  'آٹھ',
#  'آٹھواں',
#  'آپ',
#  'آپس',
#  'آگ،',
#  'آگیا',
#  'آگے',
#  'آگے،',
#  'آگ۔',
#  'آہ',
#  'آہستگی',
#  'آہستہ',
#  'آہنگی',
#  'آیا',
#  'آیا،',
#  'آیا۔',
#  'اب',
#  'اب،',
#  'ابھی',
#  'اترا',
#  'اترنے',
#  'اترے،',
#  'اتنا',
#  'اتنی',
#  'اتنے',
#  'اجتماع',
#  'احترام',
#  'احساس',
# ...

# %%
len(set(text))
# Out:
# 2009

# %%
len(set(text)) / len(text)
# Out:
# 0.17996954223774972

# %%
text.count("آسمان")
# Out:
# 10

# %%
text[10]
# Out:
# 'تھی،'

# %%
from nltk import bigrams
list(bigrams(['اس کا', 'میں سے','آپ', 'سے','تک']))
# Out:
# [('اس کا', 'میں سے'), ('میں سے', 'آپ'), ('آپ', 'سے'), ('سے', 'تک')]

# %%
# Generate bigrams
bigrams_list = list(bigrams(text))
print(bigrams_list[:10])  # Preview first 10 bigrams
# Out:
# [('جوناتھن', 'لیونگسٹن'), ('لیونگسٹن', 'سیگل'), ('سیگل', '-'), ('-', 'ایک'), ('ایک', 'کہانی'), ('کہانی', 'حصہ'), ('حصہ', 'ایک'), ('ایک', 'یہ'), ('یہ', 'صبح'), ('صبح', 'تھی،')]

# %%
text.collocations()
# Out:
# آؤٹ کاسٹ; بارے میں; جوناتھن لیونگسٹن; اپنے پروں; لیونگسٹن سیگل;
# جوناتھن سیگل; طلوع آفتاب; براہ راست; ٹھیک ہے،; ماہی گیری; طالب علم;
# رہے تھے۔; دور چٹانوں; آخر کار; ہوا میں; رہا ہے۔; چار ہزار; جانتا تھا;
# ساحل سمندر; کبھی نہیں

# %%
from nltk import FreqDist
fdist1 = FreqDist(text)
print(fdist1)
# Out:
# <FreqDist with 2009 samples and 11163 outcomes>

# %%
fdist1.most_common(50)
# Out:
# [('کے', 368),
#  ('اس', 295),
#  ('اور', 275),
#  ('سے', 251),
#  ('میں', 230),
#  ('کی', 221),
#  ('ایک', 206),
#  ('نے', 203),
#  ('وہ', 192),
#  ("''", 190),
#  ('کو', 139),
#  ('``', 117),
#  ('پر', 113),
#  ('نہیں', 112),
#  ('آپ', 103),
#  ('ہے۔', 99),
#  ('کا', 97),
#  ('کہ', 96),
#  ('!', 96),
#  ('.', 89),
#  ('یہ', 86),
#  ('جوناتھن', 83),
#  ('کر', 76),
#  ('تھا۔', 72),
#  ('لیے', 68),
#  ('گل', 66),
#  ('کیا', 65),
#  ('ہے', 60),
#  ('اپنے', 59),
#  ('ہے،', 59),
#  ('ہو', 58),
#  ('جو', 58),
#  ('ہم', 53),
#  ('ساتھ', 49),
#  ('ہوا', 47),
#  ('زیادہ', 47),
#  ('...', 46),
#  ('بھی', 45),
#  ('لیکن', 44),
#  ('ہیں۔', 43),
#  ('تھا', 40),
#  ('رفتار', 38),
#  ('طرف', 38),
#  ('پروں', 37),
#  ('رہا', 36),
#  ('بہت', 36),
#  ('سب', 36),
#  ('ہیں', 36),
#  ('تک', 35),
#  ('وقت', 35)]

# %%
fdist1['آزادی']
# Out:
# 6

# %%
V = set(text)
long_words = [w for w in V if len(w) > 15]
sorted(long_words)
# Out:
# ['دیکھیں-جونتھن-میں-ہوا',
#  'لیکن-بلاسٹ-یہ-میں-بس-نہیں',
#  'میں-اچھا-تیز-اسٹاپس-آپ',
#  'یہ-آخری-تین-پوائنٹس']

# %%
fdist5=FreqDist(text)
sorted(w for w in set(text) if len(w)>7 and fdist5[w]>7)
# Out:
# ['انسٹرکٹر', 'جوناتھن،', 'لیونگسٹن']

# %%
[len(w) for w in text]
# Out:
# [7,
#  8,
#  4,
#  1,
#  3,
#  5,
#  3,
#  3,
#  2,
#  3,
#  4,
#  3,
#  3,
#  4,
#  2,
#  4,
#  2,
#  5,
#  3,
#  4,
#  6,
#  5,
#  4,
#  2,
#  3,
#  3,
#  2,
#  5,
#  2,
#  3,
#  4,
#  3,
#  4,
#  2,
#  4,
#  2,
#  9,
#  3,
#  2,
#  2,
#  3,
#  3,
#  3,
#  4,
#  5,
#  2,
#  4,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  4,
#  4,
#  3,
#  4,
#  3,
#  5,
#  2,
#  5,
#  2,
#  3,
#  4,
#  4,
#  2,
#  3,
#  3,
#  5,
#  2,
#  2,
#  4,
#  4,
#  4,
#  5,
#  2,
#  6,
#  3,
#  4,
#  3,
#  4,
#  2,
#  4,
#  7,
#  8,
#  4,
#  3,
#  2,
#  3,
#  4,
#  5,
#  3,
#  2,
#  2,
#  4,
#  2,
#  2,
#  4,
#  4,
#  4,
#  5,
#  4,
#  4,
#  7,
#  3,
#  3,
#  6,
#  3,
#  3,
#  4,
#  3,
#  2,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  4,
#  2,
#  5,
#  1,
#  5,
#  2,
#  4,
#  3,
#  2,
#  2,
#  5,
#  5,
#  2,
#  4,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  2,
#  3,
#  3,
#  2,
#  2,
#  2,
#  3,
#  2,
#  2,
#  4,
#  2,
#  6,
#  4,
#  5,
#  2,
#  2,
#  2,
#  5,
#  4,
#  2,
#  2,
#  5,
#  2,
#  2,
#  4,
#  1,
#  2,
#  2,
# ...

# %%
fdist=FreqDist(len(W) for W in text)
fdist
# Out:
# FreqDist({2: 3457, 4: 2777, 3: 2729, 5: 1202, 6: 473, 1: 231, 7: 213, 8: 62, 9: 11, 10: 2, ...})

# %%
fdist1.hapaxes()
# Out:
# ['کہانی',
#  'چمکایا',
#  'گیر',
#  'جھنجھوڑا،',
#  'ڈاج',
#  'مصروف',
#  'نکلیں،',
#  'پرے،',
#  'جالے',
#  'پاؤں،',
#  'اٹھائی،',
#  'بٹی',
#  'سرگوشی',
#  'کرتی،',
#  'شدید',
#  'ارتکاز',
#  'کیں،',
#  'سانس',
#  'روکی،',
#  'سنگل',
#  'لڑتے،',
#  'رکتے۔',
#  'سٹال',
#  'رسوا',
#  'عزتی',
#  'شرم،',
#  'پھیلا',
#  'کانپنے',
#  'حقائق',
#  'زحمت',
#  'طریقہ۔',
#  'ذریعے،',
#  'اہمیت',
#  'مقبول',
#  'بنانے',
#  'خرچ',
#  'سیکڑوں',
#  'بناتے',
#  'نصف،',
#  'معمول',
#  'ہوئیں،',
#  'فلیٹ',
#  'ویک',
#  'پیروں',
#  'چھوا۔',
#  'پھسلنا',
#  'سلائڈ',
#  'لمبائی',
#  'پیسنگ،',
#  'لوگوں',
#  'جون؟',
#  'پیلیکن،',
#  'الباٹراس',
#  'کھاتے؟',
#  'ہڈیوں',
#  'ماں۔',
#  'سکتا،',
#  'دیکھو،',
#  'رحمی',
#  'موسم',
#  'سرما',
#  'گی،',
#  'مچھلیاں',
#  'گہرائی',
#  'تیر',
#  'ضروری',
#  'کاروبار',
#  'گلائیڈ',
#  'سکتے،',
#  'بھولنا',
#  'اطاعت',
#  'برتاؤ',
#  'طرح؛',
#  'چیخیں',
#  'ماریں',
#  'لڑا۔',
#  'گھاٹوں',
#  'گرد،',
#  'سکریپ',
#  'خوری۔',
#  'بوجھ',
#  'جیتی',
#  'اینکووی',
# ...

# %%
fdist=FreqDist(text)

# %%
fdist[text]+=1

# %%
fdist['پرواز']
# Out:
# 34

# %%
fdist.freq('پرواز')
# Out:
# 0.003045503403797922

# %%
fdist.N()
# Out:
# 11164

# %%
fdist.max()
# Out:
# 'کے'

# %%
fdist.tabulate()
# Out:
#                                                   کے                                                   اس                                                  اور                                                   سے                                                  میں                                                   کی                                                  ایک                                                   نے                                                   وہ                                                   ''                                                   کو                                                   ``                                                   پر                                                 نہیں                                                   آپ                                                  ہے۔                                                   کا                                                   کہ                                             
# ...

# %%
for text in fdist:
    print(text,end=' ')
# Out:
# کے اس اور سے میں کی ایک نے وہ '' کو `` پر نہیں آپ ہے۔ کا کہ ! . یہ جوناتھن کر تھا۔ لیے گل کیا ہے اپنے ہے، ہو جو ہم ساتھ ہوا زیادہ ... بھی لیکن ہیں۔ تھا رفتار طرف پروں رہا بہت سب ہیں تک وقت جب گیا پرواز کرنے گیا۔ تم ریوڑ تھا، اسے سیگل اب کوئی کچھ ان پھر طرح ہوں فلیچر صرف رہے سکتے ہزار سکتا کسی میل ہی سو ہیں، شروع تو اپنی اگر تھی۔ کرتے کہا، بارے اڑنا یہاں کوشش ہر پاس یا کیا۔ فی تھے۔ ساحل مجھے ہوں۔ جس دو لمحے آواز جگہ فٹ طور دور کام گھنٹہ زمین سمندر خود اڑ لئے پہلے انہیں کہا۔ دن پنکھ رہی دیکھا کبھی دوسرے اوپر اتنا زندگی ہیں؟ جنت نیچے نہ ہوئے دوبارہ بار گلوں واپس دیا انہوں جیسے آؤٹ کاسٹ لیونگسٹن - مشق آنکھیں بے ہے؟ ٹھیک باہر آہستہ سیگل، اندر سطح کم جسم ہونے نہیں، ابھی تھی تیز میرے وہاں ضرورت ہوا، بند ایسا تھے، انسٹرکٹر کہا پانی آسمان کی۔ چیز سوچ گئے چاہتا جوناتھن، نہیں۔ غوطہ سیکھنے آگے ہوں، رات خوشی بزرگ کرتا پرندے کہاں یاد چیانگ نئے ہجوم اپنا گا، جانے لیے، تھے مشکل کیوں حاصل سر دیا۔ گا اسی بھول بگلے گیا، سیکھا عظیم کریں۔ کھڑے چاہتے کرنا جا ہو۔ گے۔ جہاں حد دنیا محبت مدد قانون تھی، جانتے 
# ...

# %%
fdist.plot()
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Matplotlib currently does not support Arabic natively.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1748 (\N{ARABIC FULL STOP}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
fdist.plot(cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Matplotlib currently does not support Arabic natively.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1748 (\N{ARABIC FULL STOP}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %%
from nltk import ConditionalFreqDist

# Define conditions and samples
conditions = ["بیچ", "مفت", "پرواز", "جوناتھن"]
samples = ["ہوا", "سمندر", "آسمان", "حرکت"]

# Example text (replace with your actual text variable)
text1 = [
    "ہوا", "سمندر", "بیچ", "اسکائی", "فلائٹ", "جوناتھن", "موشن", "مفت"
    "سمندر", "آسمان", "ہوا", "حرکت", "بیچ", "پرواز"
]

# Pair each word with a condition based on some logic
pairs = []
for word in text1:
    if word in ["ہوا", "سمندر"]:  # Words associated with 'Beach' or 'Free'
        pairs.append(("بیچ", word))
    if word in ["آسمان", "حرکت"]:  # Words associated with 'Flight' or 'Jonathan'
        pairs.append(("پرواز", word))
    if word in ["سمندر", "آسمان"]:  # Words associated with 'Free'
        pairs.append(("مفت", word))
    if word in ["جوناتھن", "حرکت"]:  # Words associated with 'Jonathan'
        pairs.append(("جوناتھن", word))

# Create the Conditional Frequency Distribution
cfd = ConditionalFreqDist(pairs)

# Tabulate the results for the defined conditions and samples
cfd.tabulate(conditions=conditions, samples=samples)
# Out:
#           ہوا سمندر آسمان  حرکت
#     بیچ     2     1     0     0
#     مفت     0     1     1     0
#   پرواز     0     0     1     1
# جوناتھن     0     0     0     1

# %%
import matplotlib.pyplot as plt
cfd.plot(title="Frequency Distribution of Words by Conditions")
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Matplotlib currently does not support Arabic natively.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sorted(w for w in set(text) if len(w) > 7 and fdist1[w] > 7)
# Out:
# ['انسٹرکٹر', 'جوناتھن،', 'لیونگسٹن']

# %%
sorted(w for w in set(text) if w.endswith('ون'))
# Out:
# ['فارچون', 'فون', 'قانون', 'پرسکون', 'پُرسکون', 'کون', 'کیلون']

# %%
sorted(w for w in set(text) if w.startswith('ال'))
# Out:
# ['الباٹراس',
#  'الجھن',
#  'الفاظ',
#  'اللو',
#  'الوداع،',
#  'الٹا',
#  'الٹی',
#  'الٹے',
#  'الکا',
#  'الگ',
#  'الہی؟',
#  'الہی۔']

# %%
sorted(item for item in set(text) if item.isdigit())
# Out:
# ['1', '7']

# %%
sorted(item for item in set(text) if item.istitle())
# Out:
# ['Flock']

# %%
sorted(term for term in set(text) if 'میں' in term)
# Out:
# ["'میں",
#  'دیکھیں-جونتھن-میں-ہوا',
#  'لیکن-بلاسٹ-یہ-میں-بس-نہیں',
#  'میں',
#  'میں-اچھا-تیز-اسٹاپس-آپ',
#  'میں،',
#  'میں؟',
#  'میں۔',
#  'ہمیں']

# %%
sorted(item for item in set(text) if item.isalpha())
# Out:
# ['Flock',
#  'a',
#  'aaakkk',
#  'grockles',
#  'kame',
#  'nedt',
#  'screes',
#  'squawks',
#  'آ',
#  'آؤ',
#  'آؤٹ',
#  'آئی',
#  'آئیڈیا',
#  'آئیے',
#  'آئے',
#  'آتا',
#  'آتی',
#  'آج',
#  'آخر',
#  'آخری',
#  'آدھا',
#  'آدھی',
#  'آدھے',
#  'آرام',
#  'آزاد',
#  'آزادی',
#  'آزمانے',
#  'آس',
#  'آسان',
#  'آسانی',
#  'آسمان',
#  'آسمانوں',
#  'آغاز',
#  'آف',
#  'آفتاب',
#  'آمدید',
#  'آنکھ',
#  'آنکھوں',
#  'آنکھیں',
#  'آنے',
#  'آواز',
#  'آٹھ',
#  'آٹھواں',
#  'آپ',
#  'آپس',
#  'آگیا',
#  'آگے',
#  'آہ',
#  'آہستگی',
#  'آہستہ',
#  'آہنگی',
#  'آیا',
#  'اب',
#  'ابھی',
#  'اترا',
#  'اترنے',
#  'اتنا',
#  'اتنی',
#  'اتنے',
#  'اجتماع',
#  'احترام',
#  'احساس',
#  'احمقانہ',
#  'اختتام',
#  'اخوان',
#  'ادا',
#  'اداس',
#  'ادھر',
#  'ارتکاز',
#  'ارد',
#  'اس',
#  'اسباق',
#  'استعمال',
#  'استقبال',
#  'اسنیپ',
#  'اسود',
#  'اسٹار',
#  'اسٹال',
#  'اسٹروک',
#  'اسٹوڈنٹ',
#  'اسٹینڈ',
#  'اسپن',
#  'اسکریز',
#  'اسی',
#  'اسے',
#  'اصل',
#  'اصلی',
#  'اصول',
# ...

# %%
sorted(item for item in set(text) if item.isalnum())
# Out:
# ['1',
#  '7',
#  'Flock',
#  'a',
#  'aaakkk',
#  'grockles',
#  'kame',
#  'nedt',
#  'screes',
#  'squawks',
#  'آ',
#  'آؤ',
#  'آؤٹ',
#  'آئی',
#  'آئیڈیا',
#  'آئیے',
#  'آئے',
#  'آتا',
#  'آتی',
#  'آج',
#  'آخر',
#  'آخری',
#  'آدھا',
#  'آدھی',
#  'آدھے',
#  'آرام',
#  'آزاد',
#  'آزادی',
#  'آزمانے',
#  'آس',
#  'آسان',
#  'آسانی',
#  'آسمان',
#  'آسمانوں',
#  'آغاز',
#  'آف',
#  'آفتاب',
#  'آمدید',
#  'آنکھ',
#  'آنکھوں',
#  'آنکھیں',
#  'آنے',
#  'آواز',
#  'آٹھ',
#  'آٹھواں',
#  'آپ',
#  'آپس',
#  'آگیا',
#  'آگے',
#  'آہ',
#  'آہستگی',
#  'آہستہ',
#  'آہنگی',
#  'آیا',
#  'اب',
#  'ابھی',
#  'اترا',
#  'اترنے',
#  'اتنا',
#  'اتنی',
#  'اتنے',
#  'اجتماع',
#  'احترام',
#  'احساس',
#  'احمقانہ',
#  'اختتام',
#  'اخوان',
#  'ادا',
#  'اداس',
#  'ادھر',
#  'ارتکاز',
#  'ارد',
#  'اس',
#  'اسباق',
#  'استعمال',
#  'استقبال',
#  'اسنیپ',
#  'اسود',
#  'اسٹار',
#  'اسٹال',
#  'اسٹروک',
#  'اسٹوڈنٹ',
#  'اسٹینڈ',
#  'اسپن',
#  'اسکریز',
#  'اسی',
#  'اسے',
#  'اصل',
# ...

# %%
sorted(w for w in set(text) if'-' in w or "index" in w)
# Out:
# ['-',
#  'اچھا-',
#  'دیکھیں-جونتھن-میں-ہوا',
#  'طرح-چاہتا',
#  'لیکن-بلاسٹ-یہ-میں-بس-نہیں',
#  'میں-اچھا-تیز-اسٹاپس-آپ',
#  'چارلس-رولینڈ',
#  'ہو-',
#  'یہ-آخری-تین-پوائنٹس']

# %%
sorted(t for t in set(tokens) if 'کے' in t)
# Out:
# ['تھکے',
#  'جھونکے',
#  'جھٹکے',
#  'روکے',
#  'سکے',
#  'سکے۔',
#  'چکے',
#  'کرکے',
#  'کے',
#  'کے،',
#  'ہلکے',
#  '\u200b\u200bکے']

# %%
longest_len=max(len(s) for s in text)
[s for s in text if len(s)==longest_len]
# Out:
# ['لیکن-بلاسٹ-یہ-میں-بس-نہیں']

# %%
from nltk import FreqDist

# Compute frequency distribution
fdist = FreqDist(text)

# Display most common words
print(fdist.most_common(10))

# Plot the frequency distribution
fdist.plot(30, cumulative=False)
# Out:
# [('کے', 368), ('اس', 295), ('اور', 275), ('سے', 251), ('میں', 230), ('کی', 221), ('ایک', 206), ('نے', 203), ('وہ', 192), ("''", 190)]
# <Axes: xlabel='Samples', ylabel='Counts'>
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1746 (\N{ARABIC LETTER YEH BARREE}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Matplotlib currently does not support Arabic natively.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1729 (\N{ARABIC LETTER HEH GOAL}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# /usr/local/lib/python3.11/dist-packages/IPython/core/events.py:89: UserWarning: Glyph 1748 (\N{ARABIC FULL STOP}) missing from font(s) DejaVu Sans.
#   func(*args, **kwargs)
# ...

# %%
# !pip install stopwordsiso

# %%
import stopwordsiso as stopwords
from collections import Counter
stopwords.has_lang('ur')
# Out:
# True

# %%
urdu_stopwords = stopwords.stopwords('ur')
print(urdu_stopwords)
# Out:
# {'ہوًے', 'لا', 'پوچھوں', 'ضت', 'یہبں', 'ًہ', 'فرد', 'غروع', 'کےرریعے', 'هسترهہ', 'گے', 'ضیذھی', 'توہیں', 'طرف', 'و', 'اچھب', 'غے', 'ہوچکب', 'ٓ آش', 'هوکٌہ', 'ہوگئی', 'اکیلا', 'اٹھبًب', 'کیوًکہ', 'درخبت', 'دیب', 'ضبتھ', 'ضیذھے', 'ثٌذکرًب', 'ثھرپور', 'ًکبلٌب', 'غبیذ', 'هڑے', 'یہ', 'اکٹھب', 'ثہتری', 'لیں', 'ثٌبرہے', 'کرتے', 'هسترم', 'پبًچ', 'ہوتب', 'رکھتی', 'کرتےہو', 'آٹھ', 'ثغیر', 'دیکھی', 'لوجی', 'اکٹھی', 'ضبدٍ', 'تھے', 'ثھراہوا', 'خبًتب', 'خیطب', 'تعذاد', 'ًبپطٌذ', 'تٌہب', 'ثٌذکرو', 'کورا', 'اپٌب', 'تبزٍ', 'زبضر', 'چھہ', 'ثٌذی', 'دی', 'کہی', 'یقیٌی', 'دیکھیں', 'گئے', 'والے', 'ترتیت', 'ارد', 'صبف', 'ہورہب', 'کررہے', 'کہ', 'کہوں', 'کرتب', 'کوئی', 'خٌبة', 'کرو', 'کہیں', 'هہرثبى', 'پوچھتب', 'لڑکپي', 'کورٍ', 'آئی', 'ثراں', 'عظین', 'رریعہ', 'ثھرا', 'ًقطہ', 'ہورہے', 'چبہب', 'ثٌذ', 'ضکتب', 'عووهی', 'ر', 'ہوں', 'ثب', 'کب', 'دکھبًب', 'کہتب', 'ضوچتب', 'ہوتی', 'دیتے', 'صورتسبل', 'ہو', 'خت', 'دوضرے', 'زقیقت', 'زکن', 'ًطجت', 'ثبری', 'خلذی', 'ہوگئے', 'ہوچکے', 'اچھی', 'دلچطپیبں', 'کیطرف', 'اضتعوبل',
# ...

# %%
# Filter tokens to find stopwords and non-stopwords
filtered_tokens = [word for word in tokens if word not in urdu_stopwords]
filtered_stopwords = [word for word in tokens if word in urdu_stopwords]

# Count unique stopwords and total number of stopwords
stopword_counts = Counter(filtered_stopwords)
total_stopwords = len(filtered_stopwords)
len_without_stopwords = len(filtered_tokens)

# Output results
print("Total Number of Tokens Present in Text:", len(tokens))
print("All Stopwords Present in Text:", stopword_counts)
print("Total Number of Stopwords:", total_stopwords)
print("\nLength of Total Text without stopwords:", len_without_stopwords)
# Out:
# Total Number of Tokens Present in Text: 11163
# ...

# %%
# wordcloud
from wordcloud import WordCloud
import matplotlib.pyplot as plt


font_path = '/content/drive/MyDrive/NotoNastaliqUrdu-Regular.ttf'

# Generate WordCloud
wordcloud = WordCloud(
    font_path=font_path,
    background_color='white',
    width=800,
    height=400
).generate(raw)


plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("Urdu Word Cloud", fontsize=16)
plt.show()

# %%
import re

# Text Normalization: remove punctuation, non-Urdu characters, and normalize white spaces
def normalize_urdu(text):
    # Remove non-Urdu characters (keeping basic Urdu, digits, spaces)
    text = re.sub(r'[^\u0600-\u06FF\s]', '', text)
    # Normalize multiple spaces
    text = re.sub(r'\s+', ' ', text)
    return text.strip()


normalized_text = normalize_urdu(" ".join(text))
print(normalized_text[:200])
# Out:
# جوناتھن لیونگسٹن سیگل ایک کہانی حصہ ایک یہ صبح تھی، اور نئے سورج نے نرمی کی لہروں میں سونا چمکایا سمندر ساحل سے ایک میل کے فاصلے پر ایک ماہی گیر کشتی نے پانی کو جھنجھوڑا، اور اس کے لیے لفظ ایک ہزار بگ

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Vectorize text
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform([normalized_text])

# Display TF-IDF values
feature_names = vectorizer.get_feature_names_out()
dense = tfidf_matrix.todense().tolist()


for word, score in zip(feature_names, dense[0]):
    print(f"{word}: {score:.3f}")
# Out:
# آؤ: 0.002
# آؤٹ: 0.013
# آئی: 0.005
# آئیڈیا: 0.002
# آئیے: 0.005
# آئے: 0.008
# آتا: 0.002
# آتی: 0.001
# آج: 0.003
# آخر: 0.008
# آخری: 0.004
# آدھا: 0.001
# آدھی: 0.002
# آدھے: 0.001
# آرام: 0.002
# آزاد: 0.004
# آزادی: 0.007
# آزمانے: 0.001
# آس: 0.001
# آسان: 0.004
# آسانی: 0.006
# آسمان: 0.011
# آسمانوں: 0.001
# آغاز: 0.002
# آف: 0.003
# آفتاب: 0.007
# آمدید: 0.001
# آنکھ: 0.003
# آنکھوں: 0.004
# آنکھیں: 0.012
# آنے: 0.004
# آواز: 0.019
# آٹھ: 0.005
# آٹھواں: 0.001
# آپ: 0.106
# آپس: 0.001
# آگ: 0.002
# آگیا: 0.002
# آگے: 0.013
# آہ: 0.005
# آہستگی: 0.001
# آہستہ: 0.011
# آہنگی: 0.001
# آیا: 0.013
# اب: 0.035
# ابھی: 0.011
# اترا: 0.001
# اترنے: 0.001
# اترے: 0.001
# اتنا: 0.014
# اتنی: 0.003
# اتنے: 0.004
# اجتماع: 0.001
# احترام: 0.001
# احساس: 0.001
# احمقانہ: 0.001
# اختتام: 0.001
# اخوان: 0.001
# ادا: 0.001
# اداس: 0.002
# ادھر: 0.002
# ارتکاز: 0.001
# ارد: 0.002
# اس: 0.305
# اسباق: 0.002
# استعمال: 0.002
# استقبال: 0.002
# اسنیپ: 0.002
# اسود: 0.001
# اسٹار: 0.001
# ...

# %%
pip install stanza

# %%
# Part-of-Speech (POS) Tagging
import stanza

stanza.download('ur')

nlp = stanza.Pipeline(lang='ur', processors='tokenize,pos')

doc = nlp(normalized_text)


for sentence in doc.sentences:
    for word in sentence.words:
        print(f"{word.text}\t{word.upos}")
# Out:
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: ur (Urdu) ...
# INFO:stanza:File exists: /root/stanza_resources/ur/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: ur (Urdu):
# ...
# | Processor | Package       |
# -----------------------------
# | tokenize  | udtb          |
# | pos       | udtb_nocharlm |
# ...
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Done loading processors!
# جوناتھن	PROPN
# لیونگسٹن	PROPN
# سیگل	PROPN
# ایک	NUM
# کہانی	NOUN
# حصہ	NOUN
# ایک	NUM
# یہ	DET
# صبح	NOUN
# تھی	AUX
# ...

# %%
# Named Entity Recognition (NER)
import stanza

stanza.download('ur')

nlp = stanza.Pipeline(lang='ur', processors='tokenize,pos,ner')

doc = nlp(normalized_text)

for ent in doc.ents:
    print(f"Text: {ent.text}\tType: {ent.type}")
# Out:
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Downloading default packages for language: ur (Urdu) ...
# INFO:stanza:File exists: /root/stanza_resources/ur/default.zip
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Downloaded file to /root/stanza_resources/resources.json
# INFO:stanza:Loading these models for language: ur (Urdu):
# ...
# | Processor | Package        |
# ------------------------------
# | tokenize  | udtb           |
# | pos       | udtb_nocharlm  |
# | ner       | ilner_nocharlm |
# ...
#
# INFO:stanza:Using device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!
# Text: جوناتھن لیونگسٹن	Type: NEP
# Text: ایک	Type: NEN
# ...

# %%
from transformers import pipeline

sentiment_pipeline = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

result = sentiment_pipeline(normalized_text[:512])
print(result)
# Out:
# Device set to use cpu
# [{'label': '3 stars', 'score': 0.32199904322624207}]
